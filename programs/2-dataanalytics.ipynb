# %%
#!pip install pandas

# %%
import pandas as pd
print("series")
runs=[40,120,180,200]
runsseries = pd.Series(runs)
print(runsseries)
print("data type ",type(runsseries))
print("shape ",runsseries.shape)
# Out:
# series
# 0     40
# 1    120
# 2    180
# 3    200
# dtype: int64
# data type  <class 'pandas.core.series.Series'>
# shape  (4,)

# %%
"""
Data frame
"""
print("data frame")
topeconomy = {
              "country":["USA","CHINA","GERMANY","JAPAN","INDIA"],
              "GDP":[27,18,4.7,4.2,4.1],
              "RANK":[1,2,3,4,5]
              }
df = pd.DataFrame(topeconomy)

print(df)
print("data type ",type(df))
print("shape ",df.shape)
# Out:
#    country   GDP  RANK
# 0      USA  27.0     1
# 1    CHINA  18.0     2
# 2  GERMANY   4.7     3
# 3    JAPAN   4.2     4
# 4    INDIA   4.1     5
# data type  <class 'pandas.core.frame.DataFrame'>
# shape  (5, 3)

# %%
mydata = pd.read_csv("https://github.com/deepanshu88/Datasets/raw/master/UploadedFiles/income.csv")
mydata
# Out:
#    Index                 State    Y2002    Y2003    Y2004    Y2005    Y2006  \
# 0      A               Alabama  1296530  1317711  1118631  1492583  1107408
# 1      A                Alaska  1170302  1960378  1818085  1447852  1861639
# 2      A               Arizona  1742027  1968140  1377583  1782199  1102568
# 3      A              Arkansas  1485531  1994927  1119299  1947979  1669191
# 4      C            California  1685349  1675807  1889570  1480280  1735069
# 5      C              Colorado  1343824  1878473  1886149  1236697  1871471
# 6      C           Connecticut  1610512  1232844  1181949  1518933  1841266
# 7      D              Delaware  1330403  1268673  1706751  1403759  1441351
# 8      D  District of Columbia  1111437  1993741  1374643  1827949  1803852
# 9      F               Florida  1964626  1468852  1419738  1362787  1339608
# 10     G               Georgia  1929009  1541565  1810773  1779091  1326846
# ...

# %%
print("columns ")
print(mydata.columns)
# Out:
# columns
# Index(['Index', 'State', 'Y2002', 'Y2003', 'Y2004', 'Y2005', 'Y2006', 'Y2007',
#        'Y2008', 'Y2009', 'Y2010', 'Y2011', 'Y2012', 'Y2013', 'Y2014', 'Y2015'],
#       dtype='object')

# %%
print("first 5 records")
mydata.head()
# Out:
# first 5 records
#   Index       State    Y2002    Y2003    Y2004    Y2005    Y2006    Y2007  \
# 0     A     Alabama  1296530  1317711  1118631  1492583  1107408  1440134
# 1     A      Alaska  1170302  1960378  1818085  1447852  1861639  1465841
# 2     A     Arizona  1742027  1968140  1377583  1782199  1102568  1109382
# 3     A    Arkansas  1485531  1994927  1119299  1947979  1669191  1801213
# 4     C  California  1685349  1675807  1889570  1480280  1735069  1812546
#
#      Y2008    Y2009    Y2010    Y2011    Y2012    Y2013    Y2014    Y2015
# 0  1945229  1944173  1237582  1440756  1186741  1852841  1558906  1916661
# 1  1551826  1436541  1629616  1230866  1512804  1985302  1580394  1979143
# 2  1752886  1554330  1300521  1130709  1907284  1363279  1525866  1647724
# 3  1188104  1628980  1669295  1928238  1216675  1591896  1360959  1329341
# 4  1487315  1663809  1624509  1639670  1921845  1156536  1388461  1644607

# %%
print("last 5 records")
mydata.tail()
# Out:
# last 5 records
#    Index          State    Y2002    Y2003    Y2004    Y2005    Y2006    Y2007  \
# 46     V       Virginia  1134317  1163996  1891068  1853855  1708715  1197698
# 47     W     Washington  1977749  1687136  1199490  1163092  1334864  1621989
# 48     W  West Virginia  1677347  1380662  1176100  1888948  1922085  1740826
# 49     W      Wisconsin  1788920  1518578  1289663  1436888  1251678  1721874
# 50     W        Wyoming  1775190  1498098  1198212  1881688  1750527  1523124
#
#       Y2008    Y2009    Y2010    Y2011    Y2012    Y2013    Y2014    Y2015
# 46  1803330  1590043  1516758  1171686  1262342  1647032  1706707  1850394
# 47  1545621  1555554  1179331  1150089  1775787  1273834  1387428  1377341
# 48  1238174  1539322  1539603  1872519  1462137  1683127  1204344  1198791
# 49  1980167  1901394  1648755  1940943  1729177  1510119  1701650  1846238
# 50  1587602  1504455  1282142  1881814  1673668  1994022  1204029  1853858

# %%
print("randomly 5 records")
mydata.sample(n=5)
# Out:
# randomly 5 records
#    Index           State    Y2002    Y2003    Y2004    Y2005    Y2006  \
# 9      F         Florida  1964626  1468852  1419738  1362787  1339608
# 45     V         Vermont  1146902  1832249  1492704  1579265  1332048
# 19     M           Maine  1582720  1678622  1208496  1912040  1438549
# 40     S  South Carolina  1631522  1803455  1425193  1458191  1538731
# 4      C      California  1685349  1675807  1889570  1480280  1735069
#
#       Y2007    Y2008    Y2009    Y2010    Y2011    Y2012    Y2013    Y2014  \
# 9   1278550  1756185  1818438  1198403  1497051  1131928  1107448  1407784
# 45  1563537  1123567  1618583  1326369  1792600  1714960  1146278  1282790
# 19  1330014  1295877  1969163  1627262  1706080  1437088  1318546  1116792
# 40  1825195  1250499  1864685  1345102  1116203  1532332  1591735  1188417
# 4   1812546  1487315  1663809  1624509  1639670  1921845  1156536  1388461
#
#       Y2015
# 9   1170389
# 45  1565924
# 19  1529233
# 40  1110655
# ...

# %%
print("10 % of  records")
mydata.sample(frac=.1)
# Out:
# 10 % of  records
#    Index                 State    Y2002    Y2003    Y2004    Y2005    Y2006  \
# 40     S        South Carolina  1631522  1803455  1425193  1458191  1538731
# 43     T                 Texas  1520591  1310777  1957713  1907326  1873544
# 18     L             Louisiana  1584734  1110625  1868456  1751920  1233709
# 8      D  District of Columbia  1111437  1993741  1374643  1827949  1803852
# 37     O                Oregon  1794912  1726665  1805445  1133510  1502242
#
#       Y2007    Y2008    Y2009    Y2010    Y2011    Y2012    Y2013    Y2014  \
# 40  1825195  1250499  1864685  1345102  1116203  1532332  1591735  1188417
# 43  1655483  1785986  1827503  1447457  1978374  1882532  1698698  1646508
# 18  1920301  1185085  1124853  1498662  1210385  1234234  1287663  1908602
# 8   1595981  1193245  1739748  1707823  1353449  1979708  1912654  1782169
# 37  1419251  1482786  1862351  1103794  1935687  1905378  1522129  1509171
#
#       Y2015
# 40  1110655
# ...

# %%
mydata.State
# Out:
# 0                  Alabama
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 14                 Indiana
# 15                    Iowa
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# 19                   Maine
# 20                Maryland
# 21           Massachusetts
# 22                Michigan
# 23               Minnesota
# 24             Mississippi
# 25                Missouri
# 26                 Montana
# 27                Nebraska
# 28                  Nevada
# 29           New Hampshire
# 30              New Jersey
# 31              New Mexico
# 32                New York
# 33          North Carolina
# ...

# %%
print( "display first 15 records")
mydata.head(15)
# Out:
# display first 15 records
#    Index                 State    Y2002    Y2003    Y2004    Y2005    Y2006  \
# 0      A               Alabama  1296530  1317711  1118631  1492583  1107408
# 1      A                Alaska  1170302  1960378  1818085  1447852  1861639
# 2      A               Arizona  1742027  1968140  1377583  1782199  1102568
# 3      A              Arkansas  1485531  1994927  1119299  1947979  1669191
# 4      C            California  1685349  1675807  1889570  1480280  1735069
# 5      C              Colorado  1343824  1878473  1886149  1236697  1871471
# 6      C           Connecticut  1610512  1232844  1181949  1518933  1841266
# 7      D              Delaware  1330403  1268673  1706751  1403759  1441351
# 8      D  District of Columbia  1111437  1993741  1374643  1827949  1803852
# 9      F               Florida  1964626  1468852  1419738  1362787  1339608
# 10     G               Georgia  1929009  1541565  1810773  1779091  1326846
# ...

# %%
print("display 2 rows")
mydata.iloc[:2]
# Out:
# display 2 rows
#   Index    State    Y2002    Y2003    Y2004    Y2005    Y2006    Y2007  \
# 0     A  Alabama  1296530  1317711  1118631  1492583  1107408  1440134
# 1     A   Alaska  1170302  1960378  1818085  1447852  1861639  1465841
#
#      Y2008    Y2009    Y2010    Y2011    Y2012    Y2013    Y2014    Y2015
# 0  1945229  1944173  1237582  1440756  1186741  1852841  1558906  1916661
# 1  1551826  1436541  1629616  1230866  1512804  1985302  1580394  1979143

# %%
print("display all records and 2 columns")
mydata.iloc[:,:2]
# Out:
# display all records and 2 columns
#    Index                 State
# 0      A               Alabama
# 1      A                Alaska
# 2      A               Arizona
# 3      A              Arkansas
# 4      C            California
# 5      C              Colorado
# 6      C           Connecticut
# 7      D              Delaware
# 8      D  District of Columbia
# 9      F               Florida
# 10     G               Georgia
# 11     H                Hawaii
# 12     I                 Idaho
# 13     I              Illinois
# 14     I               Indiana
# 15     I                  Iowa
# 16     K                Kansas
# 17     K              Kentucky
# 18     L             Louisiana
# 19     M                 Maine
# 20     M              Maryland
# 21     M         Massachusetts
# 22     M              Michigan
# 23     M             Minnesota
# 24     M           Mississippi
# 25     M              Missouri
# 26     M               Montana
# 27     N              Nebraska
# ...

# %%
mydata["State"]
# Out:
# 0                  Alabama
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 14                 Indiana
# 15                    Iowa
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# 19                   Maine
# 20                Maryland
# 21           Massachusetts
# 22                Michigan
# 23               Minnesota
# 24             Mississippi
# 25                Missouri
# 26                 Montana
# 27                Nebraska
# 28                  Nevada
# 29           New Hampshire
# 30              New Jersey
# 31              New Mexico
# 32                New York
# 33          North Carolina
# ...

# %%
mydata.loc[:,["State","Y2002"]]
# Out:
#                    State    Y2002
# 0                Alabama  1296530
# 1                 Alaska  1170302
# 2                Arizona  1742027
# 3               Arkansas  1485531
# 4             California  1685349
# 5               Colorado  1343824
# 6            Connecticut  1610512
# 7               Delaware  1330403
# 8   District of Columbia  1111437
# 9                Florida  1964626
# 10               Georgia  1929009
# 11                Hawaii  1461570
# 12                 Idaho  1353210
# 13              Illinois  1508356
# 14               Indiana  1776918
# 15                  Iowa  1499269
# 16                Kansas  1509054
# 17              Kentucky  1813878
# 18             Louisiana  1584734
# 19                 Maine  1582720
# 20              Maryland  1579713
# 21         Massachusetts  1647582
# 22              Michigan  1295635
# 23             Minnesota  1729921
# 24           Mississippi  1983285
# 25              Missouri  1221316
# ...
